# %% [markdown]
# ## Задание

# %% [markdown]
# Создать ноутбук, в котором выполнить решение вычислительной задачи (например, задачи из области физики, экономики, математики, статистики и т. д.) требующей построения круговой диаграммы, условие которой предварительно необходимо согласовать с
# преподавателем.

# %% [markdown]
# В студенческой группе состоят студенты двух специальностей: "Информатика" и "Экономика". Студентов на специальности "Информатика" - 45%, а на специальности "Экономика" - 55%. Необходимо проанализировать соотношение студентов по специальностям и представить результаты в виде круговой диаграммы.

# %%
import matplotlib.pyplot as plt

# %%
# Данные о количестве студентов по специальностям
specialties = ['Информатика', 'Экономика']
students_count = [53, 102]

# %%
# Создание круговой диаграммы
colors = ['#1f77b4', '#ff7f0e']
plt.pie(students_count, labels=specialties, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Соотношение студентов по специальностям')
plt.show()
