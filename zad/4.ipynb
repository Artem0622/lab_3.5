# %% [markdown]
# ## Задание

# %% [markdown]
# *Найти какое-либо изображение в сети Интернет. Создать ноутбук, в котором будет отображено выбранное изображение средствами библиотеки matplotlib по URL из сети Интернет.*

# %%
import matplotlib.pyplot as plt

from PIL import Image
import requests

from io import BytesIO

response = requests.get('https://oir.mobi/uploads/posts/2021-05/1621520869_20-oir_mobi-p-koshki-milota-zhivotnie-krasivo-foto-20.jpg')
img = Image.open(BytesIO(response.content))

plt.imshow(img)
